# %%
from read_data import *

# %%
#events, history = read_data(prepend='/Users/RSHAW/Library/Application Support/EpicBanana/Yogurt Commercial 3')
events, history = read_data()

# %%
timeline(events)

# %%
maxes(events)
# Out:
# most disturbing: 22: when Tom commited cannibalism (cannibalism) 350
# most disgusting: 22: when Tom commited cannibalism (cannibalism) 500
# most chaos: 21: when Tom ate Puddle(Clone) (eating) 200
# most offensive: 21: when Tom ate Puddle(Clone) (eating) 500
# most positive: 4: when Tom said I'm full! (speech act) 25

# %%
hist(events)

# %%
cumplot(events)

# %%
pie(events)

# %%
highestn(events)
# Out:
# Top 3 most disturbing
# 0: Tom commited cannibalism
# 1: Tom ate Puddle(Clone)
# 2: Tom said I don't feel so good!!
#
# Top 3 most disgusting
# 0: Tom commited cannibalism
# 1: Tom ate Puddle(Clone)
# 2: Tom ate Puddle(Clone)
#
# Top 3 most chaos
# 0: Tom ate Puddle(Clone)
# 1: Tom commited cannibalism
# 2: horizon collided with droplet
#
# Top 3 most offensive
# 0: Tom ate Puddle(Clone)
# 1: Tom commited cannibalism
# 2: yogurt was spilled
#
# Top 3 most positive
# 0: Tom said I'm full!
# 1: Tom said I'm full!
# 2: Tom ate yogurt
#
# notable events
# eating: Tom ate Puddle(Clone)
# cannibalism: Tom commited cannibalism
# collision: horizon collided with droplet
#
# notable deltas
# cannibalism: Tom commited cannibalism
# eating: Tom ate Puddle(Clone)
# speech act: Tom said I'm full!
#
# 250 Tom commited cannibalism
# 87 Tom ate Puddle(Clone)
# 0 Tom said I don't feel so good!!
# 425 Tom commited cannibalism
# 0 Tom ate Puddle(Clone)
# 40 Tom ate Puddle(Clone)
# ...
